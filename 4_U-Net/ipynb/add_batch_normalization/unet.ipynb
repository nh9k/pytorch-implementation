# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !pwd
# !ls
# Out:
# /content/drive/My Drive/Pytorch_Study/Unet
# CustomDataset.py  eval.py  __pycache__	UNet-error-concat.py
# datasets	  output   train.py	UNet.py

# %%
cd drive/My\ Drive/Pytorch_Study/Unet
# Out:
# /content/drive/My Drive/Pytorch_Study/Unet

# %%
# !python3 train.py
# Out:
# Namespace(b1=0.5, b2=0.99, batch_size=4, data_dir='./datasets', epochs=100, learning_rate=0.0001, num_workers=4, resume=False)
# UNet(
#   (down1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (down2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
# ...

# %%
# !python3 eval.py
# Out:
# Namespace(batch_size=4, data_dir='./datasets', num_workers=4, result_dir='./output', resume=True)
# test: [Batch 0/1] [Loss: 0.103]
# shape: torch.Size([3, 1, 512, 512]) torch.Size([3, 1, 512, 512]) torch.Size([3, 1, 512, 512])
# outputs tensor([[[[ 2.6846,  2.5898,  2.6605,  ...,  3.0607,  3.0631,  2.9485],
#           [ 2.4366,  2.4324,  2.4372,  ...,  2.8098,  2.9413,  2.9973],
#           [ 2.6514,  2.4445,  2.7129,  ...,  2.7143,  2.8047,  2.8638],
#           ...,
#           [ 2.9641,  3.2859,  3.0131,  ...,  2.5191,  2.6314,  2.6542],
#           [ 2.8251,  3.1987,  2.9456,  ...,  2.7608,  2.8753,  2.8287],
#           [ 2.7322,  3.1040,  2.8214,  ...,  3.0051,  2.9848,  3.0236]]],
#
#
#         [[[-0.3563, -1.8285, -2.4317,  ...,  3.0466,  3.0275,  2.8083],
#           [-1.6360, -3.6415, -4.2898,  ...,  3.1229,  3.0804,  3.0610],
#           [-2.3733, -4.6698, -5.1670,  ...,  3.0740,  3.0383,  3.0197],
#           ...,
# ...
